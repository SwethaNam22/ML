# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('Salary_dataset.csv',sep=',',header=None)
df.columns = ['', 'YearsExperience','Salary']
df.head(5)
# Out:
#       YearsExperience   Salary
# 0  0              1.2  39344.0
# 1  1              1.4  46206.0
# 2  2              1.6  37732.0
# 3  3              2.1  43526.0
# 4  4              2.3  39892.0

# %%
X=df[['YearsExperience']]
y=df['Salary']
plt.scatter(X,y)                     #plotting the data
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=23)

# %%
scaler_X = StandardScaler()

Xtrain_scaled=scaler_X.fit_transform(X_train)
Xtest_scaled=scaler_X.fit_transform(X_test)
y_train
# Out:
# 0      39344.0
# 14     61112.0
# 5      56643.0
# 11     55795.0
# 2      37732.0
# 25    105583.0
# 23    113813.0
# 28    122392.0
# 29    121873.0
# 7      54446.0
# 12     56958.0
# 13     57082.0
# 27    112636.0
# 22    101303.0
# 9      57190.0
# 8      64446.0
# 6      60151.0
# 19     93941.0
# Name: Salary, dtype: float64

# %%
reg = LinearRegression()
reg.fit(Xtrain_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(Xtest_scaled)
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error: 37853864.826560445

# %%
plt.scatter(Xtest_scaled,y_test)
plt.plot(Xtest_scaled,y_pred,color='red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
new_experience = np.array([[7]])
new_experience_scaled = scaler_X.transform(new_experience)
predicted_salary = reg.predict(new_experience_scaled)
print(f'Predicted salary for {new_experience[0][0]} years of experience: ${predicted_salary[0]:.2f}')
# Out:
# Predicted salary for 7 years of experience: $95068.10
# c:\Users\sweth\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
